# %% [markdown]
# print("HELLO PYTHON IT  HAS BEEN A WHILE NOW")

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/USER/Downloads/subnational_cases_deaths.csv")

# %%
print(df.head(10))
# Out:
#    location1   Unnamed: 1        Date  total_cases  new_cases  \
# 0  Australia  Australian   13-03-2020            1        1.0
# 1  Australia  Australian   14-03-2020            1        0.0
# 2  Australia  Australian   15-03-2020            1        0.0
# 3  Australia  Australian   16-03-2020            2        1.0
# 4  Australia  Australian   17-03-2020            2        0.0
# 5  Australia  Australian   18-03-2020            3        1.0
# 6  Australia  Australian   19-03-2020            4        1.0
# 7  Australia  Australian   20-03-2020            6        2.0
# 8  Australia  Australian   21-03-2020            9        3.0
# 9  Australia  Australian   22-03-2020           19       10.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# 0                0.14             0         0.0                  0.0
# 1                0.14             0         0.0                  0.0
# 2                0.14             0         0.0                  0.0
# ...

# %%
print(df.info(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 9 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   location1            1048575 non-null  object
#  1   Unnamed: 1           1048575 non-null  object
#  2   Date                 1048575 non-null  object
#  3   total_cases          1048575 non-null  int64
#  4   new_cases            1046457 non-null  float64
#  5   new_cases_smoothed   1046244 non-null  float64
#  6   total_deaths         1048575 non-null  int64
#  7   new_deaths           1046457 non-null  float64
#  8   new_deaths_smoothed  1046243 non-null  float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 72.0+ MB
# None

# %%
print(df.describe())
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.048575e+06  1.046457e+06        1.046244e+06  1.048575e+06
# mean   8.504209e+03  3.449577e+01        3.286704e+01  1.519372e+02
# std    4.062276e+04  5.798996e+02        2.417051e+02  7.593654e+02
# min    1.000000e+00 -2.763520e+05       -1.079957e+04  0.000000e+00
# 25%    2.920000e+02  0.000000e+00        1.000000e+00  4.000000e+00
# 50%    1.389000e+03  2.000000e+00        4.290000e+00  2.700000e+01
# 75%    4.376000e+03  1.300000e+01        1.600000e+01  8.100000e+01
# max    2.010964e+06  1.502510e+05        3.620600e+04  2.779800e+04
#
#          new_deaths  new_deaths_smoothed
# count  1.046457e+06         1.046243e+06
# mean   4.540951e-01         4.515393e-01
# std    5.356324e+00         3.511060e+00
# min   -5.900000e+02        -8.529000e+01
# 25%    0.000000e+00         0.000000e+00
# 50%    0.000000e+00         0.000000e+00
# 75%    0.000000e+00         2.900000e-01
# ...

# %%
print(df.drop_duplicates())
# Out:
#              location1   Unnamed: 1        Date  total_cases  new_cases  \
# 0            Australia  Australian   13-03-2020            1        1.0
# 1            Australia  Australian   14-03-2020            1        0.0
# 2            Australia  Australian   15-03-2020            1        0.0
# 3            Australia  Australian   16-03-2020            2        1.0
# 4            Australia  Australian   17-03-2020            2        0.0
# ...                ...          ...         ...          ...        ...
# 1048570  United States     Missouri  06-09-2020          118        1.0
# 1048571  United States     Missouri  07-09-2020          118        0.0
# 1048572  United States     Missouri  08-09-2020          119        1.0
# 1048573  United States     Missouri  09-09-2020          121        2.0
# 1048574  United States     Missouri  10-09-2020          121        0.0
#
#          new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# ...

# %%
print(df.head())
# Out:
#    location1   Unnamed: 1        Date  total_cases  new_cases  \
# 0  Australia  Australian   13-03-2020            1        1.0
# 1  Australia  Australian   14-03-2020            1        0.0
# 2  Australia  Australian   15-03-2020            1        0.0
# 3  Australia  Australian   16-03-2020            2        1.0
# 4  Australia  Australian   17-03-2020            2        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# 0                0.14             0         0.0                  0.0
# 1                0.14             0         0.0                  0.0
# 2                0.14             0         0.0                  0.0
# 3                0.29             0         0.0                  0.0
# 4                0.29             0         0.0                  0.0

# %%
df.head(10)
# Out:
#    location1   Unnamed: 1        Date  total_cases  new_cases  \
# 0  Australia  Australian   13-03-2020            1        1.0
# 1  Australia  Australian   14-03-2020            1        0.0
# 2  Australia  Australian   15-03-2020            1        0.0
# 3  Australia  Australian   16-03-2020            2        1.0
# 4  Australia  Australian   17-03-2020            2        0.0
# 5  Australia  Australian   18-03-2020            3        1.0
# 6  Australia  Australian   19-03-2020            4        1.0
# 7  Australia  Australian   20-03-2020            6        2.0
# 8  Australia  Australian   21-03-2020            9        3.0
# 9  Australia  Australian   22-03-2020           19       10.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# 0                0.14             0         0.0                  0.0
# 1                0.14             0         0.0                  0.0
# 2                0.14             0         0.0                  0.0
# ...

# %%
df.shape
# Out:
# (1048575, 9)

# %%
df.columns
# Out:
# Index(['location1', 'Unnamed: 1', 'Date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed'],
#       dtype='object')

# %%
df.isnull()

df.isnull().sum()
# Out:
# location1                 0
# Unnamed: 1                0
# Date                      0
# total_cases               0
# new_cases              2118
# new_cases_smoothed     2331
# total_deaths              0
# new_deaths             2118
# new_deaths_smoothed    2332
# dtype: int64

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.048575e+06  1.046457e+06        1.046244e+06  1.048575e+06
# mean   8.504209e+03  3.449577e+01        3.286704e+01  1.519372e+02
# std    4.062276e+04  5.798996e+02        2.417051e+02  7.593654e+02
# min    1.000000e+00 -2.763520e+05       -1.079957e+04  0.000000e+00
# 25%    2.920000e+02  0.000000e+00        1.000000e+00  4.000000e+00
# 50%    1.389000e+03  2.000000e+00        4.290000e+00  2.700000e+01
# 75%    4.376000e+03  1.300000e+01        1.600000e+01  8.100000e+01
# max    2.010964e+06  1.502510e+05        3.620600e+04  2.779800e+04
#
#          new_deaths  new_deaths_smoothed
# count  1.046457e+06         1.046243e+06
# mean   4.540951e-01         4.515393e-01
# std    5.356324e+00         3.511060e+00
# min   -5.900000e+02        -8.529000e+01
# 25%    0.000000e+00         0.000000e+00
# 50%    0.000000e+00         0.000000e+00
# 75%    0.000000e+00         2.900000e-01
# ...

# %%
#df.drop(["new_cases_smoothed", "new_cases", "total_deaths", "new_deaths", "new_deaths_smoothed"],  axis = 1, inplace = True)

# %%
df.head()
# Out:
#    location1   Unnamed: 1        Date  total_cases  new_cases  \
# 0  Australia  Australian   13-03-2020            1        1.0
# 1  Australia  Australian   14-03-2020            1        0.0
# 2  Australia  Australian   15-03-2020            1        0.0
# 3  Australia  Australian   16-03-2020            2        1.0
# 4  Australia  Australian   17-03-2020            2        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# 0                0.14             0         0.0                  0.0
# 1                0.14             0         0.0                  0.0
# 2                0.14             0         0.0                  0.0
# 3                0.29             0         0.0                  0.0
# 4                0.29             0         0.0                  0.0

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.048575e+06  1.046457e+06        1.046244e+06  1.048575e+06
# mean   8.504209e+03  3.449577e+01        3.286704e+01  1.519372e+02
# std    4.062276e+04  5.798996e+02        2.417051e+02  7.593654e+02
# min    1.000000e+00 -2.763520e+05       -1.079957e+04  0.000000e+00
# 25%    2.920000e+02  0.000000e+00        1.000000e+00  4.000000e+00
# 50%    1.389000e+03  2.000000e+00        4.290000e+00  2.700000e+01
# 75%    4.376000e+03  1.300000e+01        1.600000e+01  8.100000e+01
# max    2.010964e+06  1.502510e+05        3.620600e+04  2.779800e+04
#
#          new_deaths  new_deaths_smoothed
# count  1.046457e+06         1.046243e+06
# mean   4.540951e-01         4.515393e-01
# std    5.356324e+00         3.511060e+00
# min   -5.900000e+02        -8.529000e+01
# 25%    0.000000e+00         0.000000e+00
# 50%    0.000000e+00         0.000000e+00
# 75%    0.000000e+00         2.900000e-01
# ...

# %%
df.to_csv("Cleaned_Dataset.csv", index = False)

# %%
print(df.head(10))
# Out:
#    location1   Unnamed: 1        Date  total_cases  new_cases  \
# 0  Australia  Australian   13-03-2020            1        1.0
# 1  Australia  Australian   14-03-2020            1        0.0
# 2  Australia  Australian   15-03-2020            1        0.0
# 3  Australia  Australian   16-03-2020            2        1.0
# 4  Australia  Australian   17-03-2020            2        0.0
# 5  Australia  Australian   18-03-2020            3        1.0
# 6  Australia  Australian   19-03-2020            4        1.0
# 7  Australia  Australian   20-03-2020            6        2.0
# 8  Australia  Australian   21-03-2020            9        3.0
# 9  Australia  Australian   22-03-2020           19       10.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# 0                0.14             0         0.0                  0.0
# 1                0.14             0         0.0                  0.0
# 2                0.14             0         0.0                  0.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df_sample = df.sample(n = 5)
plt.figure(figsize = (10, 6))
plt.plot(df_sample["Date"], df_sample["new_cases"])
plt.title("DAILY NEW COVID 19 CASES")
plt.xlabel("Date")
plt.ylabel("new_cases")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %%
df["Date"] = pd. to_datetime(df["Date"])
df_grouped = df.groupby(df["Date"].dt. to_period("M")).sum()
df_grouped.plot()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1232\3364135468.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Date"] = pd. to_datetime(df["Date"])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 df["Date"] = pd. to_datetime(df["Date"])
# ----> 2 df_grouped = df.groupby(df["Date"].dt. to_period("M")).sum()
#       3 df_grouped.plot()
#
# File ~\anaconda3\anaconda\Lib\site-packages\pandas\core\groupby\groupby.py:2263, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    2258 else:
#    2259     # If we are grouping on categoricals we want unobserved categories to
#    2260     # return zero, rather than the default of NaN which the reindexing in
#    2261     # _agg_general() returns. GH #31422
# ...

# %%
df[df["location1"] == "Australia"]
# Out:
#       location1         Unnamed: 1       Date  total_cases  new_cases  \
# 0     Australia        Australian  2020-03-13            1        1.0
# 1     Australia        Australian  2020-03-14            1        0.0
# 2     Australia        Australian  2020-03-15            1        0.0
# 3     Australia        Australian  2020-03-16            2        1.0
# 4     Australia        Australian  2020-03-17            2        0.0
# ...         ...                ...        ...          ...        ...
# 5555  Australia  Western Australia 2022-01-06         1215        9.0
# 5556  Australia  Western Australia 2022-01-07         1221        6.0
# 5557  Australia  Western Australia 2022-01-08         1231       10.0
# 5558  Australia  Western Australia 2022-01-09         1231        0.0
# 5559  Australia  Western Australia 2022-01-10         1239        8.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# ...

# %%
df_grouped = df.groupby("location1")["total_deaths"].max().sort_values(ascending = False).head(10)

# %%
print(df_grouped)
# Out:
# location1
# United States     27798
# Canada            11966
# China              4512
# Australia          1593
# France              835
# Netherlands         194
# United Kingdom      118
# Denmark              15
# New Zealand           0
# Name: total_deaths, dtype: int64

# %%
plt.figure(figsize = (20, 10))
plt.bar(df_grouped.index, df_grouped.values, color = "skyblue")
plt.xlabel("Country")
plt.ylabel("total Cases")
plt.title("Top 10 Countries with the highest covid 19 cases")
plt.xticks(rotation = 0)
plt.tight_layout()
plt.show()

# %%
df_grouped = df.groupby("location1")["total_deaths"].max().sort_values(ascending = False).head(10)
plt.figure(figsize = (20, 10))
sns.barplot(x = df_grouped.index, y = df_grouped.values, palette="viridis")
plt.xticks(rotation = 45)
plt.xlabel("Country")
plt.ylabel("Total Cases")
plt.title("Top 10 countries with Highest Covid-19 Cases")
plt.tight_layout()
plt.show()
